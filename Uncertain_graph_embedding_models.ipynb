# %% [markdown]
# <a href="https://colab.research.google.com/github/AlinaTkachenko/knowledge_graph_embedding/blob/main/Uncertain_graph_embedding_models.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Installation

# %%
# !conda create -n unKR python=3.8
# !conda activate unKR
# Out:
# /bin/bash: line 1: conda: command not found
# /bin/bash: line 1: conda: command not found

# %%
# !git clone https://github.com/seucoin/unKR.git
# %cd unKR
# !pip install -r requirements.txt
# !python setup.py install
# Out:
# Cloning into 'unKR'...
# remote: Enumerating objects: 1013, done.
# remote: Counting objects: 100% (129/129), done.
# remote: Compressing objects: 100% (114/114), done.
# remote: Total 1013 (delta 72), reused 39 (delta 15), pack-reused 884
# Receiving objects: 100% (1013/1013), 48.38 MiB | 13.57 MiB/s, done.
# Resolving deltas: 100% (500/500), done.
# /content/unKR
# ERROR: Could not find a version that satisfies the requirement torch==1.9.1+cu111 (from versions: 1.11.0, 1.12.0, 1.12.1, 1.13.0, 1.13.1, 2.0.0, 2.0.1, 2.1.0, 2.1.1, 2.1.2, 2.2.0, 2.2.1, 2.2.2)
# ERROR: No matching distribution found for torch==1.9.1+cu111
# running install
# /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/cmd.py:66: SetuptoolsDeprecationWarning: setup.py install is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` directly.
# ...

# %%
# !pip install unKR
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 527.7/527.7 kB 5.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 841.5/841.5 kB 31.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 952.4/952.4 kB 55.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 63.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 27.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 267.1/267.1 kB 29.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 10.4 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...

# %% [markdown]
# # ChatGPT recommendations

# %% [markdown]
# # Try models

# %%
# %cd unKR
# Out:
# /content/unKR

# %%
# !python demo/UKGEdemo.py
# Out:
# 2024-04-20 23:42:01.365216: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-20 23:42:01.365270: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-20 23:42:01.366685: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-20 23:42:02.535406: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# This demo is for testing UKGE
# Global seed set to 321
# ppi5k
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# ...

# %%
# !pip install --upgrade pytorch-lightning
# Out:
# ...
#   Using cached pytorch_lightning-2.2.2-py3-none-any.whl (801 kB)
# ...
#   Attempting uninstall: pytorch-lightning
#     Found existing installation: pytorch-lightning 1.5.10
#     Uninstalling pytorch-lightning-1.5.10:
#       Successfully uninstalled pytorch-lightning-1.5.10
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# unkr 0.8.1 requires pytorch_lightning==1.5.10, but you have pytorch-lightning 2.2.2 which is incompatible.
# ...

# %%
pip install pytorch_lightning==1.5.10
# Out:
# ...
#   Using cached pytorch_lightning-1.5.10-py3-none-any.whl (527 kB)
# ...
#   Attempting uninstall: pytorch_lightning
#     Found existing installation: pytorch-lightning 2.2.2
#     Uninstalling pytorch-lightning-2.2.2:
#       Successfully uninstalled pytorch-lightning-2.2.2
# ...

# %%
from torch.optim.lr_scheduler import MultiStepLR

# Assuming 'optimizer' is already defined
scheduler_object = MultiStepLR(optimizer, milestones=[30, 80], gamma=0.1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-f1f339da9184> in <cell line: 4>()
#       2
#       3 # Assuming 'optimizer' is already defined
# ----> 4 scheduler_object = MultiStepLR(optimizer, milestones=[30, 80], gamma=0.1)
#
# NameError: name 'optimizer' is not defined
